# %%
#create visual for notebook times on decision tree

# %%
import matplotlib.pyplot as plt 
  
# x axis values 
x = [1,2,3] 
# corresponding y axis values 
y = [19.159,,] 
  
# plotting the points  
plt.plot(x, y) 
  
# naming the x axis 
plt.xlabel('x - axis') 
# naming the y axis 
plt.ylabel('y - axis') 
  
# giving a title to my graph 
plt.title('Cluster Runtimes!') 
  
# function to show the plot 
plt.show()

# %%
#Done using 6 cores and 20gb memory

# %%
1: 17m and 41.085s = 
The best max_depth is  10 , best minInstancesPerNode =  6 , testing rmse =  47.59616996179739
2: 22m and 19.451s 
The best max_depth is  10 , best minInstancesPerNode =  7 , testing rmse =  47.863746126935375
3: 53m and 43.144s
The best max_depth is  9 , best minInstancesPerNode =  7 , testing rmse =  47.868732317160806
4: 58m and 21.306s
The best max_depth is  10 , best minInstancesPerNode =  7 , testing rmse =  47.599112762846175
5: 70m and 40.384s
The best max_depth is  10 , best minInstancesPerNode =  7 , testing rmse =  47.76520463982353

# %%
Since we realized that another reason time could be increasing was that we did not rename folder or file paths so the workers first had to overwrite old data/files on top of processing the existing code. The incomplete times below showcase our efforts and tests to measure the impact that the change has on the runtimes.
5: 47m and 1.534s
The best max_depth is  10 , best minInstancesPerNode =  6 , testing rmse =  47.70474452853713
4: 52m and 17.048s
The best max_depth is  10 , best minInstancesPerNode =  7 , testing rmse =  47.968543189861954
3:

# %%
#Done using 4 cores and 16gb memory
