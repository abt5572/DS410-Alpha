# %%
import pyspark
import pandas as pd
import csv

# %%
from pyspark import SparkContext
from pyspark.sql import SparkSession
from pyspark.sql.types import StructField, StructType, StringType, LongType, IntegerType, FloatType
from pyspark.sql.functions import col, column
from pyspark.sql.functions import expr
from pyspark.sql.functions import split
from pyspark.sql import Row

# %%
ss=SparkSession.builder.master("local").appName("Project").getOrCreate()

# %%
ss.sparkContext.setCheckpointDir("~/scratch")

# %%
#test = ss.read.csv("wildfiredb.csv", header=True, inferSchema=True)

# %%
#test.show()

# %%
# %%time
chunksize1 = 100000
df_list = []

for df in pd.read_csv("wildfiredb.csv", chunksize=chunksize1, engine='python'):

    df_list.append(df)
# Out:
# CPU times: user 7min 16s, sys: 24.3 s, total: 7min 40s
# Wall time: 7min 42s

# %%
result = pd.concat(df_list)
# Out:
# 24

# %%
result.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-0f73a9d1931c> in <module>
# ----> 1 result.dtypes
#
# NameError: name 'result' is not defined

# %%
len(df_list)

# %%
df_list[0]
# Out:
#        Polygon_ID    acq_date    frp  Neighbour  Neighbour_frp  CBC2014_max  \
# 0            7234  2012-11-06   3.20       7233            0.0         13.0
# 1            7380  2012-11-06   5.10       7233            0.0        100.0
# 2            7381  2014-11-02   0.90       7233            0.0        100.0
# 3            7381  2012-11-06   3.20       7233            0.0        100.0
# 4           15290  2015-11-14  14.60      15437            0.0        100.0
# ...           ...         ...    ...        ...            ...          ...
# 99995      705136  2012-08-19   2.05     704703            2.6         17.0
# 99996      705136  2012-08-20   0.90     704703            1.3         17.0
# 99997      705136  2012-08-16   1.10     704703            0.0         17.0
# 99998      705137  2012-08-16   1.10     704703            0.0         12.0
# 99999      705137  2012-08-15   6.75     704703            1.1         12.0
#
#        CBC2014_min  CBC2014_median  CBC2014_sum  CBC2014_mode  ...  \
# 0              0.0             9.0       1303.0           0.0  ...
# 1              0.0             8.0       1457.0           0.0  ...
# 2              0.0             9.0       1448.0           0.0  ...
# 3              0.0             9.0       1448.0           0.0  ...
# 4              0.0             8.0       1262.0           0.0  ...
# ...            ...             ...          ...           ...  ...
# 99995          0.0            11.0       1719.0           0.0  ...
# 99996          0.0            11.0       1719.0           0.0  ...
# 99997          0.0            11.0       1719.0           0.0  ...
# 99998          0.0            11.0       1118.0           0.0  ...
# 99999          0.0            11.0       1118.0           0.0  ...
#
#        Neighbour_NVC2016_mode  Neighbour_NVC2016_count  \
# 0                      7200.0                      169
# 1                      7200.0                      169
# 2                      7200.0                      169
# 3                      7200.0                      169
# 4                      6308.0                      169
# ...                       ...                      ...
# 99995                  7196.0                      169
# 99996                  7196.0                      169
# 99997                  7196.0                      169
# 99998                  7196.0                      169
# 99999                  7196.0                      169
#
#        Neighbour_NVC2016_mean  Neighbour_SLP2016_max  Neighbour_SLP2016_min  \
# 0                   6111.3906                   37.0                    3.0
# 1                   6111.3906                   37.0                    3.0
# 2                   6111.3906                   37.0                    3.0
# 3                   6111.3906                   37.0                    3.0
# 4                   6113.2900                   35.0                    4.0
# ...                       ...                    ...                    ...
# 99995               6330.6274                   39.0                    4.0
# 99996               6330.6274                   39.0                    4.0
# 99997               6330.6274                   39.0                    4.0
# 99998               6330.6274                   39.0                    4.0
# 99999               6330.6274                   39.0                    4.0
#
#        Neighbour_SLP2016_median  Neighbour_SLP2016_sum  \
# 0                          17.0                 3109.0
# 1                          17.0                 3109.0
# 2                          17.0                 3109.0
# 3                          17.0                 3109.0
# 4                          25.0                 3951.0
# ...                         ...                    ...
# 99995                      23.0                 3721.0
# 99996                      23.0                 3721.0
# 99997                      23.0                 3721.0
# 99998                      23.0                 3721.0
# 99999                      23.0                 3721.0
#
#        Neighbour_SLP2016_mode  Neighbour_SLP2016_count  Neighbour_SLP2016_mean
# 0                        24.0                      169               18.396450
# 1                        24.0                      169               18.396450
# 2                        24.0                      169               18.396450
# 3                        24.0                      169               18.396450
# 4                        24.0                      169               23.378698
# ...                       ...                      ...                     ...
# 99995                    24.0                      169               22.017752
# 99996                    24.0                      169               22.017752
# 99997                    24.0                      169               22.017752
# 99998                    24.0                      169               22.017752
# 99999                    24.0                      169               22.017752
#
# [100000 rows x 397 columns]

# %%
#df = pandas.read_csv("wildfiredb.csv")
#sample = df.head(100)
fire_small = df_list[0]
fire_small.to_csv("fire_small.csv")

# %%
trial = pd.read_csv("fire_small.csv")

# %%
trial.dtypes
# Out:
# Unnamed: 0                    int64
# Polygon_ID                    int64
# acq_date                     object
# frp                         float64
# Neighbour                     int64
#                              ...
# Neighbour_SLP2016_median    float64
# Neighbour_SLP2016_sum       float64
# Neighbour_SLP2016_mode      float64
# Neighbour_SLP2016_count       int64
# Neighbour_SLP2016_mean      float64
# Length: 398, dtype: object

# %%
df_spark_test = ss.createDataFrame(trial)

# %%
#df_spark_test.printSchema()

# %%
small = ss.read.csv("fire_small.csv", header=True, inferSchema=True)

# %%
#sparkDF=ss.createDataFrame(test) 
#sparkDF.printSchema()

# %%
#test.printSchema()

# %%
#?
#import csv
#def read_csv(file_name):
#    with open(file_name, "r") as f:
#        reader = csv.reader(f)
#        for row in reader:
#            yield row
        
#for row in read_csv("wildfiredb.csv"):
#    process_row(row)

# %%
col_list = list(small.columns)

# %%
col_list[0]
# Out:
# 'Polygon_ID'

# %%
col_list.pop(0)
# Out:
# 'frp'

# %%
#test.select('acq_date').show()

# %%
col_list.pop(1)
# Out:
# 'acq_date'

# %%
col_list[0]
# Out:
# 'Polygon_ID'

# %%
#col_list

# %%
#col_list2 = [str(i) for i in col_list]

# %%
from pyspark import SparkFiles
from pyspark.sql import SparkSession
from pyspark.ml.regression import LinearRegression
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder

# %%
# Define the feature and label columns
assembler = VectorAssembler(inputCols=col_list, outputCol="features")

data = assembler.transform(test)
final_data = data.select("features", "frp")

#Split data into training and testing
train_data, test_data = final_data.randomSplit([0.8, 0.2], seed=42)

# %%
lasso_regression = LinearRegression(featuresCol="features", labelCol="frp", elasticNetParam=1)

# %%
# Define the hyperparameter grid
param_grid = ParamGridBuilder() \
    .addGrid(lasso_regression.regParam, [0.001, 0.01, 0.1, 1.0]) \
    .build()

# Create the cross-validator
evaluator = RegressionEvaluator(predictionCol="prediction", labelCol= "frp", metricName="rmse")
cross_validator = CrossValidator(estimator=lasso_regression,
                                 estimatorParamMaps=param_grid,
                                 evaluator=evaluator,
                                 numFolds=5)

# Train the model with the best hyperparameters
cv_model = cross_validator.fit(train_data)
lasso_model = cv_model.bestModel

# %%
coefficients = lasso_model.coefficients
intercept = lasso_model.intercept

print("Coefficients: ", coefficients)
print("Intercept: {:.3f}".format(intercept))
# Out:
# Coefficients:  [-4.0082730585216675e-07,0.17285110452649988,0.020910665251392648,0.04189467007744582,-0.007903376597185452,-0.00012712024505152347,-0.0008921977479548169,-0.0009573631552220804,-0.033258858671392166,0.20813375577054222,-0.2608430060914046,-0.40792877692814494,-0.000780705104965768,-0.019521978962196762,-0.000979145544455624,-0.1458709696183059,-0.10037605679982188,0.5463467171103334,-0.03910833268460147,-0.0001693824085016323,0.0901553737314781,-0.0009449679848998347,-0.02042616859164153,-0.03517965586354084,-0.03311888913035344,0.055696161704046135,0.000194546797436618,-0.06353691310407253,-0.0009481305948146104,0.03978576408471704,0.020910665251392648,0.041894670077445864,-0.00790337659718545,-0.00012712024505152678,-0.0008921977479548148,-0.0008928300709861038,-0.033259987916903995,0.01417094945813466,0.005017121958921633,-0.049335827460513994,2.5844736507471112e-05,-0.0652149552902989,-0.0008912914129694479,-0.0001480670082430381,0.05198208651201663,-0.00616877375769822,0.048271021103429866,0.00024708886388698383,0.016634340334122352,-0.0009281894276247115,0.03977681604727913,-0.044708281776652765,0.009458788966487533,-0.024033857013547703,-0.00019428524361788562,0.01887795180321656,-0.0008928300709854014,-0.029940117541522458,-0.025198566568491895,-0.027426038011863354,0.05042757274768817,8.86223434552489e-05,-0.0024945734028974883,-0.0009326512239422633,0.023051641983371698,0.0003672480997730834,2.1799362059417274e-05,0.00025396732027954016,-6.510720083837946e-07,-0.00718940788167939,-0.0007907416901396274,-0.00023934624965045163,-0.0027023702565347426,0.004255807466304421,-0.006527211913051558,-6.354372495914863e-05,-0.0018585459044768713,-0.0007907707825217669,-0.009938369016029897,-0.0018367174793969062,-0.004552128646060328,0.003547490140641684,3.2448040348843206e-07,-0.006823140214906608,-0.0009398382873148956,0.0002922439834115868,-5.8223206874723476e-05,-2.038794517601279e-06,-0.0003241472131266334,-1.026868549519522e-06,-0.00015405958452127197,-0.0008928300709897828,-0.00018926728014491016,-0.07100527030709615,-0.0021315788595787665,-0.024245857321888768,-0.00021732539487372712,0.013753408227405835,-0.0008928300709940931,-0.02373154693427035,-0.03047666028378058,-0.0008851194545261911,-0.003469060133145246,-1.399632134580099e-05,0.0451201349318462,-0.0008928300709910437,-0.002457366958198084,-0.009396893985904332,0.0020633492540237503,0.007399107156501977,0.0003043530225704652,0.0100066523653072,-0.0008928300709887432,0.012563479146163386,0.06027783192026173,-0.0019606552948503186,0.022704433930670096,0.00016376683797329915,0.023873343949756928,-0.000892830070990468,0.018002068330010307,0.06368618113443313,-0.002582073666831374,0.03636509136175202,7.430466527680553e-05,-0.012420741387947559,-0.0008928300709820806,0.017841763108341003,-0.0011287118878891163,0.0034057805773287713,-0.0011577250499239596,6.918859495743055e-05,0.010375896977847838,-0.0008928300709680656,0.011837443138031698,0.0006449702210536071,-0.0025866503720583488,0.00011819313299816711,1.7731027772985739e-06,-0.0014898739258901322,-0.0008928300709576026,0.00030947222601288477,0.0003475518106161692,-0.00037039982265764924,0.0009243444713180375,1.4719360526603898e-06,0.00021846975970178862,-0.0008928300709524364,0.0007092846985427879,0.00038840274530524627,-0.0,-0.0007247036130119059,-4.263483454670781e-06,0.0018142046243879517,-0.000892830070997298,-0.002149844248295541,-0.0006781341173391325,0.005370355583337385,0.0015817999819329,-3.99303832111029e-06,-0.0029365631624952457,-0.0008928300709961819,-0.002335242679930779,-0.012296266906551641,-0.0015690217279059147,-0.03950260532747464,-0.00015218640146987266,-0.06436588681771181,-0.0008928300710183817,-0.019747312257275225,0.0029496160482191808,0.008087358826682677,-0.0007913379796097932,-2.0247486516059685e-06,8.517815293535923e-06,-0.0008928300710329626,-5.5424592986490196e-05,0.0001151557315879903,0.0013022461376666502,-0.001547636803189476,-2.4348068332527115e-06,0.000176860658 ...
# Intercept: 18.141

# %%
feature_importance = sorted(list(zip(data.columns[:-1], map(abs, coefficients))), key=lambda x: x[1], reverse=True)

print("Feature Importance:")
for feature, importance in feature_importance:
    print("  {}: {:.3f}".format(feature, importance))
# Out:
# Feature Importance:
#   Neighbour_CBD2012_mode: 0.920
#   CBD2012_mode: 0.546
#   CBC2014_count: 0.408
#   Neighbour_CBD2016_max: 0.350
#   Neighbour_CBC2014_mode: 0.286
#   CBC2014_mode: 0.261
#   Neighbour_CBD2012_sum: 0.232
#   Neighbour_CBD2012_median: 0.208
#   CBC2014_sum: 0.208
#   Polygon_ID: 0.173
#   CBD2012_median: 0.146
#   Neighbour_CBD2016_count: 0.143
#   NVC2016_count: 0.133
#   Neighbour_CBD2012_max: 0.120
#   Neighbour_CBC2014_sum: 0.114
#   Neighbour_CBD2012_count: 0.108
#   Neighbour_NVC2016_mode: 0.101
#   CBD2012_sum: 0.100
#   SLP2016_max: 0.100
#   Neighbour_SLP2016_max: 0.096
#   CBD2016_max: 0.090
#   Neighbour_CBH2012_mode: 0.090
#   SLP2016_mode: 0.090
#   Neighbour_CBH2012_median: 0.084
#   Neighbour_EVC2016_sum: 0.081
#   Neighbour_CC2014_count: 0.079
#   ELEV2016_sum: 0.071
#   Neighbour_CBD2016_mode: 0.071
#   CBH2016_max: 0.065
#   Neighbour_EVH2012_sum: 0.065
#   FVC2016_max: 0.064
#   EVH2012_sum: 0.064
#   CBH2012_max: 0.064
#   Neighbour_NVC2016_sum: 0.061
#   EVC2016_sum: 0.060
#   Neighbour_CBH2016_max: 0.060
#   Neighbour_CC2012_sum: 0.060
#   Neighbour_CBD2016_sum: 0.057
#   CBD2016_count: 0.056
#   CBH2016_sum: 0.052
#   Neighbour_EVC2012_max: 0.052
#   NVC2016_mode: 0.051
#   Neighbour_CC2012_median: 0.051
#   CC2014_count: 0.050
#   CBH2014_count: 0.049
#   CBH2016_count: 0.048
#   Neighbour_CBD2016_median: 0.048
#   Neighbour_CBH2016_sum: 0.048
#   Neighbour_CBH2014_sum: 0.046
#   EVC2014_max: 0.045
#   CC2012_sum: 0.045
#   SLP2016_count: 0.044
#   Neighbour_CBH2012_count: 0.044
#   Neighbour_ELEV2016_sum: 0.044
#   CBH2012_mode: 0.042
#   frp: 0.042
#   CBH2012_median: 0.040
#   CC2012_median: 0.040
#   FCCS2014_count: 0.040
#   CBD2012_count: 0.039
#   Neighbour_CC2012_count: 0.039
#   Neighbour_EVH2012_max: 0.039
#   Neighbour_CC2014_max: 0.039
#   Neighbour_CC2012_max: 0.037
#   EVH2012_count: 0.036
#   Neighbour_EVC2016_count: 0.036
#   Neighbour_CC2014_sum: 0.036
#   CBD2016_sum: 0.035
#   NVC2016_sum: 0.035
#   Neighbour_EVC2012_sum: 0.035
#   CBH2014_median: 0.033
#   CBC2014_median: 0.033
#   CBD2016_mode: 0.033
#   Neighbour_FVC2016_max: 0.033
#   Neighbour_CC2012_mode: 0.033
#   Neighbour_CBH2016_count: 0.031
#   EVC2012_sum: 0.030
#   CC2014_median: 0.030
#   Neighbour_CC2014_median: 0.028
#   CC2014_mode: 0.027
#   Neighbour_CBH2014_max: 0.027
#   Neighbour_CBC2014_max: 0.027
#   Neighbour_CBH2012_sum: 0.027
#   SLP2016_sum: 0.027
#   Neighbour_CBH2016_mode: 0.027
#   Neighbour_CBH2014_count: 0.026
#   CC2014_sum: 0.025
#   Neighbour_EVH2014_median: 0.025
#   ELEV2016_count: 0.024
#   CC2012_count: 0.024
#   EVH2012_max: 0.024
#   EVC2012_median: 0.024
#   Neighbour_EVH2012_count: 0.023
#   CC2016_median: 0.023
#   EVC2016_count: 0.023
#   Neighbour_EVH2012_median: 0.023
#   Neighbour_CBC2014_median: 0.022
#   Neighbour_CBH2014_median: 0.022
#   Neighbour_EVC2016_max: 0.021
#   Neighbour_CBH2012_max: 0.021
#   acq_date: 0.021
#   CBH2012_sum: 0.021
#   CBD2016_median: 0.020
#   FVC2016_median: 0.020
#   CBD2012_max: 0.020
#   CC2014_max: 0.019
#   EVH2012_median: 0.018
#   EVH2014_median: 0.018
#   Neighbour_ELEV2016_count: 0.018
#   CC2012_max: 0.017
#   Neighbour_CBC2014_count: 0.017
#   Neighbour_FCCS2014_count: 0.016
#   SLP2016_median: 0.015
#   Neighbour_CC2016_median: 0.015
#   CBH2014_sum: 0.014
#   Neighbour_EVC2014_max: 0.014
#   Neighbour_EVC2012_count: 0.014
#   EVC2012_max: 0.014
#   Neighbour_FVC2016_median: 0.013
#   Neighbour_CH2012_sum: 0.013
#   EVC2016_median: 0.013
#   Neighbour_CC2016_max: 0.012
#   Neighbour_CC2014_mode: 0.012
#   EVH2014_max: 0.012
#   FCCS2014_sum: 0.012
#   EVH2016_median: 0.012
#   Neighbour_EVC2012_median: 0.011
#   Neighbour_CBH2016_median: 0.011
#   EVH2016_max: 0.010
#   EVC2016_max: 0.010
#   CH2014_median: 0.010
#   Neighbour_EVC2014_median: 0.010
#   CC2012_mode: 0.009
#   EVC2014_sum: 0.009
#   Neighbour_FVH2016_max: 0.009
#   Neighbour_EVC2016_median: 0.008
#   FVC2016_mode: 0.008
#   Neighbour: 0.008
#   CBH2012_count: 0.008
#   EVC2014_count: 0.007
#   Neighbour_EVH2016_max: 0.007
#   CH2012_max: 0.007
#   Neighbour_EVH2016_mode: 0.007
#   Neighbour_CH2014_median: 0.007
#   CH2016_max: 0.007
#   CH2012_count: 0.007
#   Neighbour_FCCS2014_mode: 0.006
#   CBH2016_mode: 0.006
#   Neighbour_SLP2016_median: 0.006
#   EVT2016_mode: 0.005
#   Neighbour_CC2016_mode: 0.005
#   CBH2014_mode: 0.005
#   Neighbour_CH2014_sum: 0.005
#   Neighbour_CBH2014_mode: 0.005
#   Neighbour_FVC2016_sum: 0.005
#   CH2014_mode: 0.005
#   CH2012_mode: 0.004
#   Neighbour_EVT2014_mode: 0.004
#   Neighbour_EVH2016_median: 0.004
#   Neighbour_EVC2012_mode: 0.004
#   Neighbour_ELEV2016_mode: 0.004
#   Neighbour_EVC2014_count: 0.004
#   Neighbour_EVH2014_sum: 0.004
#   Neighbour_CH2012_count: 0.004
#   Neighbour_EVH2012_mode: 0.004
#   CH2014_count: 0.004
#   Neighbour_FVC2016_count: 0.004
#   Neighbour_FCCS2014_sum: 0.003
#   EVC2012_count: 0.003
#   EVH2014_mode: 0.003
#   Neighbour_CH2012_mode: 0.003
#   FVC2016_sum: 0.003
#   FCCS2014_max: 0.003
#   Neighbour_CC2016_count: 0.003
#   Neighbour_CH2016_max: 0.003
#   Neighbour_CH2014_max: 0.003
#   Neighbour_FVT2016_mode: 0.003
#   CH2012_sum: 0.003
#   EVH2016_mode: 0.003
#   EVH2012_mode: 0.003
#   Neighbour_EVT2016_mode: 0.003
#   Neighbour_FVC2016_mode: 0.002
#   CC2016_max: 0.002
#   Neighbour_EVT2014_count: 0.002
#   EVC2014_median: 0.002
#   Neighbour_EVT2016_median: 0.002
#   Neighbour_FCCS2014_max: 0.002
#   FCCS2014_median: 0.002
#   Neighbour_EVH2014_max: 0.002
#   EVT2016_median: 0.002
#   ELEV2016_mode: 0.002
#   EVC2014_mode: 0.002
#   EVC2016_mode: 0.002
#   CH2014_max: 0.002
#   CH2014_sum: 0.002
#   EVT2016_max: 0.002
#   Neighbour_CH2014_mode: 0.002
#   EVT2016_count: 0.002
#   FCCS2014_mode: 0.002
#   FVH2016_count: 0.002
#   EVT2012_max: 0.001
#   Neighbour_EVT2016_count: 0.001
#   Neighbour_CBC2014_mean: 0.001
#   Neighbour_CC2016_sum: 0.001
#   FVH2016_mode: 0.001
#   Neighbour_FVH2016_mode: 0.001
#   Neighbour_EVT2016_sum: 0.001
#   Neighbour_CH2014_min: 0.001
#   Neighbour_NVC2016_min: 0.001
#   Neighbour_FVT2016_min: 0.001
#   Neighbour_CBD2012_min: 0.001
#   Neighbour_CBC2014_min: 0.001
#   Neighbour_FVH2016_min: 0.001
#   Neighbour_CBD2016_min: 0.001
#   Neighbour_CBH2012_min: 0.001
#   Neighbour_CBH2014_min: 0.001
#   Neighbour_CBH2016_min: 0.001
#   Neighbour_CC2012_min: 0.001
#   Neighbour_EVT2014_min: 0.001
#   Neighbour_CH2012_min: 0.001
#   Neighbour_CC2014_min: 0.001
#   Neighbour_CC2016_min: 0.001
#   Neighbour_EVT2012_min: 0.001
#   Neighbour_EVT2016_min: 0.001
#   Neighbour_EVH2012_min: 0.001
#   Neighbour_FCCS2014_min: 0.001
#   Neighbour_EVH2014_min: 0.001
#   Neighbour_FVC2016_min: 0.001
#   Neighbour_EVC2016_min: 0.001
#   Neighbour_EVC2014_min: 0.001
#   Neighbour_EVC2012_min: 0.001
#   Neighbour_CH2016_min: 0.001
#   Neighbour_ELEV2016_min: 0.001
#   Neighbour_EVH2016_min: 0.001
#   EVH2014_count: 0.001
#   Neighbour_SLP2016_min: 0.001
#   Neighbour_CH2012_median: 0.001
#   EVH2014_sum: 0.001
#   Neighbour_NVC2016_count: 0.001
#   Neighbour_FVT2016_max: 0.001
#   Neighbour_FVT2016_sum: 0.001
#   FVT2016_sum: 0.001
#   Neighbour_EVT2012_mode: 0.001
#   CBD2012_min: 0.001
#   CBC2014_min: 0.001
#   CBH2012_min: 0.001
#   CBD2016_min: 0.001
#   CH2016_min: 0.001
#   CC2016_min: 0.001
#   CC2012_min: 0.001
#   EVT2012_count: 0.001
#   FVT2016_count: 0.001
#   NVC2016_min: 0.001
#   FVH2016_min: 0.001
#   FVT2016_min: 0.001
#   FVC2016_min: 0.001
#   SLP2016_min: 0.001
#   EVT2016_min: 0.001
#   FCCS2014_min: 0.001
#   EVC2012_min: 0.001
#   EVC2014_min: 0.001
#   EVH2012_min: 0.001
#   ELEV2016_min: 0.001
#   EVC2016_min: 0.001
#   CBH2014_min: 0.001
#   CC2014_min: 0.001
#   EVH2014_min: 0.001
#   EVH2016_min: 0.001
#   EVT2012_min: 0.001
#   EVT2014_min: 0.001
#   CBC2014_max: 0.001
#   CBH2014_max: 0.001
#   CBH2016_min: 0.001
#   EVC2012_mode: 0.001
#   Neighbour_EVT2012_count: 0.001
#   FVC2016_count: 0.001
#   CH2014_min: 0.001
#   CH2012_min: 0.001
#   FVT2016_mode: 0.001
#   CBC2014_mean: 0.001
#   NVC2016_max: 0.001
#   NVC2016_median: 0.001
#   EVT2014_count: 0.001
#   Neighbour_EVC2014_sum: 0.001
#   EVT2014_median: 0.001
#   EVT2016_sum: 0.001
#   EVH2016_sum: 0.001
#   Neighbour_CBD2016_mean: 0.001
#   Neighbour_CH2012_max: 0.001
#   Neighbour_FVH2016_count: 0.001
#   Neighbour_EVT2014_median: 0.001
#   Neighbour_EVT2016_max: 0.000
#   Neighbour_EVT2012_sum: 0.000
#   Neighbour_CH2014_count: 0.000
#   Neighbour_EVC2016_mode: 0.000
#   Neighbour_FVT2016_median: 0.000
#   EVT2014_sum: 0.000
#   EVT2012_mode: 0.000
#   CC2016_sum: 0.000
#   Neighbour_CH2016_sum: 0.000
#   EVT2012_sum: 0.000
#   Neighbour_EVH2014_mode: 0.000
#   CH2016_count: 0.000
#   Neighbour_CBH2016_mean: 0.000
#   Neighbour_EVH2016_count: 0.000
#   EVT2012_median: 0.000
#   EVC2014_mean: 0.000
#   Neighbour_EVT2014_sum: 0.000
#   CH2016_median: 0.000
#   Neighbour_ELEV2016_median: 0.000
#   Neighbour_FVT2016_count: 0.000
#   Neighbour_FVH2016_median: 0.000
#   Neighbour_CBD2012_mean: 0.000
#   CC2016_count: 0.000
#   CBH2016_mean: 0.000
#   Neighbour_EVT2012_max: 0.000
#   CH2012_median: 0.000
#   Neighbour_CH2016_count: 0.000
#   Neighbour_CH2016_mode: 0.000
#   EVT2014_max: 0.000
#   ELEV2016_mean: 0.000
#   Neighbour_EVH2016_sum: 0.000
#   CBD2016_mean: 0.000
#   CC2012_mean: 0.000
#   SLP2016_mean: 0.000
#   Neighbour_CBH2012_mean: 0.000
#   Neighbour_NVC2016_median: 0.000
#   ELEV2016_median: 0.000
#   Neighbour_EVH2014_count: 0.000
#   FVT2016_max: 0.000
#   Neighbour_CC2012_mean: 0.000
#   Neighbour_EVT2014_max: 0.000
#   CBD2012_mean: 0.000
#   Neighbour_EVT2012_median: 0.000
#   EVC2016_mean: 0.000
#   FVT2016_median: 0.000
#   ELEV2016_max: 0.000
#   FCCS2014_mean: 0.000
#   CBH2016_median: 0.000
#   Neighbour_EVC2016_mean: 0.000
#   CBH2012_mean: 0.000
#   Neighbour_frp: 0.000
#   Neighbour_EVH2012_mean: 0.000
#   EVH2016_count: 0.000
#   Neighbour_EVC2014_mode: 0.000
#   FVH2016_sum: 0.000
#   Neighbour_FCCS2014_mean: 0.000
#   Neighbour_NVC2016_max: 0.000
#   NVC2016_mean: 0.000
#   Neighbour_ELEV2016_mean: 0.000
#   Neighbour_CC2014_mean: 0.000
#   CC2014_mean: 0.000
#   Neighbour_FVH2016_sum: 0.000
#   EVH2012_mean: 0.000
#   EVH2014_mean: 0.000
#   Neighbour_CBH2014_mean: 0.000
#   CH2012_mean: 0.000
#   Neighbour_ELEV2016_max: 0.000
#   CH2016_sum: 0.000
#   FVH2016_median: 0.000
#   Neighbour_CH2012_mean: 0.000
#   Neighbour_FCCS2014_median: 0.000
#   Neighbour_EVC2014_mean: 0.000
#   Neighbour_NVC2016_mean: 0.000
#   CBH2014_mean: 0.000
#   CC2016_mode: 0.000
#   Neighbour_EVH2014_mean: 0.000
#   EVC2012_mean: 0.000
#   Neighbour_CH2014_mean: 0.000
#   Neighbour_EVT2016_mean: 0.000
#   FVH2016_max: 0.000
#   Neighbour_EVC2012_mean: 0.000
#   Neighbour_FVH2016_mean: 0.000
#   Neighbour_EVT2014_mean: 0.000
#   Neighbour_FVC2016_mean: 0.000
#   EVT2014_mean: 0.000
#   EVT2016_mean: 0.000
#   FVT2016_mean: 0.000
#   Neighbour_EVH2016_mean: 0.000
#   FVH2016_mean: 0.000
#   Neighbour_FVT2016_mean: 0.000
#   CH2016_mode: 0.000
#   FVC2016_mean: 0.000
#   EVH2016_mean: 0.000
#   Neighbour_CC2016_mean: 0.000
#   EVT2012_mean: 0.000
#   Neighbour_CH2016_mean: 0.000
#   CH2016_mean: 0.000
#   CC2016_mean: 0.000
#   Neighbour_EVT2012_mean: 0.000
#   _c0: 0.000
#   CH2014_mean: 0.000
#   EVT2014_mode: 0.000
#   Neighbour_CH2016_median: 0.000

# %%
# Make predictions on the test data
predictions = lasso_model.transform(test_data)

# Evaluate the model
rmse = evaluator.evaluate(predictions)
r2 = RegressionEvaluator(predictionCol="prediction", labelCol="frp", metricName="r2").evaluate(predictions)

print("Root Mean Squared Error (RMSE):", rmse)
print("Coefficient of Determination (R2):", r2)
# Out:
# Root Mean Squared Error (RMSE): 51.77642480836823
# Coefficient of Determination (R2): 0.04698393371238918
